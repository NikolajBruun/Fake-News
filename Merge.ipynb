# %% [markdown]
# ## Merge the cleaned training set with the

# %%
import pandas as pd

# %%
Cleaned_DF = pd.read_csv("C:/Users/Danie/GDS/CSV/Fully_cleaned_Training_set.csv")

# %%
CLeaned_BBC_articles = pd.read_csv("")

# %% [markdown]
# ### Check if columns match

# %%
Cleaned_DF.head()
# Out:
#    Unnamed: 0         id                   domain        type  \
# 0      5862.0  2604712.0          sputniknews.com        bias
# 1      1875.0  6796114.0           patriotpost.us        bias
# 2      1623.0  8630682.0              nytimes.com    reliable
# 3      6726.0  7779458.0          sputniknews.com        bias
# 4      9299.0  1789093.0  conservativerefocus.com  conspiracy
#
#                                                  url  \
# 0  https://sputniknews.com/military/2015112510307...
# 1        https://patriotpost.us/articles/36153/print
# 2  https://www.nytimes.com/2003/02/21/world/threa...
# 3  https://sputniknews.com/asia/20151110102986427...
# 4  http://conservativerefocus.com/blogs/index.php...
#
#                    scraped_at                 inserted_at  \
# 0  2017-11-13T18:09:27.760857  2018-02-07 23:39:33.852671
# 1  2017-11-27T01:15:02.476695  2018-02-08 19:18:34.468038
# 2  2018-02-11 00:37:24.071395  2018-02-11 00:14:20.346838
# ...

# %%
CLeaned_BBC_articles.head()

# %%
CLeaned_BBC_articles.rename(columns={'old_column_name': 'new_column_name'}, inplace=True)

# %%
combined_df = Cleaned_DF.merge(CLeaned_BBC_articles, on="article_id", how="outer")  # "outer" keeps all rows
